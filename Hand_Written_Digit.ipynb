# %%
#Liberaries
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import numpy as np

# %%
#Dataset loading
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 99s 9us/step

# %%
#Normalaizing
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)

# %%
# #Model
# model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
# model.add(tf.keras.layers.Dense(128, activation='relu'))
# model.add(tf.keras.layers.Dense(128, activation='relu'))
# model.add(tf.keras.layers.Dense(10, activation='softmax'))

# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# model.fit(x_train, y_train, epochs=10)
# Out:
# c:\Users\Moksh Maheshwari\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9212 - loss: 0.2687
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9663 - loss: 0.1084
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9768 - loss: 0.0751
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9826 - loss: 0.0533
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9864 - loss: 0.0415
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9894 - loss: 0.0310
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9915 - loss: 0.0254
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9931 - loss: 0.0205
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9934 - loss: 0.0188
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9947 - loss: 0.0157

# %%
# loss, accuracy = model.evaluate(x_test, y_test)
# print(accuracy)
# print(loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.9692 - loss: 0.1347
# 0.9692000150680542
# 0.13469894230365753

# %%
# model.save('Hand_Written.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model = tf.keras.models.load_model('Hand_Written.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
image_number = 1
while os.path.isfile(f"digits/digit{image_number}.png"):
    try:
      img = cv2.imread(f"digits/digit{image_number}.png")[:,:,0]
      img = np.invert(np.array([img]))
      prediction = model.predict(img)
      print(np.argmax(prediction))
      plt.imshow(img[0], cmap=plt.cm.binary)
      plt.show()

    except:
      print("Error")
    finally:
      image_number += 1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 7
